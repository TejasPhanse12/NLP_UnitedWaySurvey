# %% [markdown]
# # **Testing the CSV constructions**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/UWSM_Community_Input_Transcripts.csv")

data
# Out:
#                                             File Name  \
# 0   EFO_75 State Street__Cumberland County, Older ...
# 1   EFO_AvestaOOB_York County, Older Adults, Rente...
# 2   EFO_Bartlett Woods_York County, Older Adults, ...
# 3   EFO_Biddeford Resiliency_York County, Under 25...
# 4   EFO_BridgtonLibrary_Cumberland County, Rural, ...
# 5   EFO_DECDSubcommittee_Both Counties, Urban, Abo...
# 6   EFO_ELU 2-18-2026 Val - Cumberland County, Urb...
# 7   EFO_GreatBay_3-3_York County, Rural, Some ALIC...
# 8   EFO_Investment Vol_Cumberland County, Urban, A...
# 9   EFO_LL Bean Talent Acquisition_Cumberland Coun...
# 10  EFO_Loaned Execs_Cumberland County, Corporate ...
# 11  EFO_MAIN_Cumberland, Urban, Immigrants, ALICE.txt
# 12  EFO_Noble Students and Ambassadors 1_York, Rur...
# 13  EFO_Noble Students and Ambassadors 2_York, Rur...
# 14               EFO_Noble Teachers 3_York, Rural.txt
# 15  EFO_SMAASpringvale_York, Older Adults, Rural, ...
# ...

# %%
data.isna().sum()
# Out:
# File Name                      0
# Name of Facilitator(s)         2
# Date of Conversation           1
# Name of Organization/Group     0
# Meeting Location               6
# Length of Time                 2
# Number of Attendees            0
# Population                     0
# Summary Keywords              12
# Conversation                   0
# dtype: int64

# %%
population_dic = {
    "Under 18" : ["high school sophomores", "College Students","College Students"],
    "Under 24" : ["under 25", "Youth","under 24","College Students","College Students"],
    "25 - 44" : [],
    "45 - 64" : ["families 55+", "55+"],
    "Over 65+" : ["older adults (over 65+)", "families Older Adults 65+","families Older adults"],
    "Prefer not to answer" : []
}

# %%
data[(data["Source File"] == "EFO_AvestaOOB_York County, Older Adults, Renters.txt") & (data["Speaker"] == "Speaker 1")].loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/nlpenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Source File'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ...
